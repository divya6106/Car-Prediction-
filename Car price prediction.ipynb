# %%
import pandas as pd

# %%
car  =  pd.read_csv("C:\\Users\\gauta\\Downloads\\Cleaned_Car_data.csv")
car
# Out:
#      Unnamed: 0                    name   company  year   Price  kms_driven  \
# 0             0     Hyundai Santro Xing   Hyundai  2007   80000       45000
# 1             1     Mahindra Jeep CL550  Mahindra  2006  425000          40
# 2             2       Hyundai Grand i10   Hyundai  2014  325000       28000
# 3             3  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4             4               Ford Figo      Ford  2012  175000       41000
# ..          ...                     ...       ...   ...     ...         ...
# 811         811      Maruti Suzuki Ritz    Maruti  2011  270000       50000
# 812         812          Tata Indica V2      Tata  2009  110000       30000
# 813         813    Toyota Corolla Altis    Toyota  2009  300000      132000
# 814         814            Tata Zest XM      Tata  2018  260000       27000
# 815         815      Mahindra Quanto C8  Mahindra  2013  390000       40000
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# ...

# %%
car["company"].unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Ford', 'Maruti', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat', 'Force',
#        'Mercedes', 'Land', 'Jaguar', 'Jeep', 'Volvo'], dtype=object)

# %%
#feature is x and price is y
X = car.drop(columns='Price')
y = car['Price']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing  import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe = OneHotEncoder()#liner regression only understand numerical value and easy to understand that why we needd this formation
#Learns patterns (e.g.std, mean, categories).
ohe.fit(X[['name','company','fuel_type']])
#transform() → Applies learned transformations.(convert 0 to 1 )
# Out:
# OneHotEncoder()

# %%
ohe.categories_
# Out:
# [array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#         'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#         'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#         'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#         'Chevrolet Beat LS', 'Chevrolet Beat LT', 'Chevrolet Beat PS',
#         'Chevrolet Cruze LTZ', 'Chevrolet Enjoy', 'Chevrolet Enjoy 1.4',
#         'Chevrolet Sail 1.2', 'Chevrolet Sail UVA', 'Chevrolet Spark',
#         'Chevrolet Spark 1.0', 'Chevrolet Spark LS', 'Chevrolet Spark LT',
#         'Chevrolet Tavera LS', 'Chevrolet Tavera Neo', 'Datsun GO T',
#         'Datsun Go Plus', 'Datsun Redi GO', 'Fiat Linea Emotion',
#         'Fiat Petra ELX', 'Fiat Punto Emotion', 'Force Motors Force',
#         'Force Motors One', 'Ford EcoSport', 'Ford EcoSport Ambiente',
#         'Ford EcoSport Titanium', 'Ford EcoSport Trend',
# ...

# %%
column_trans = make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),remainder='passthrough')

""" make_column_transformer() → Applies transformations to specific columns.
    OneHotEncoder() → Converts categorical values into binary columns.
    ['Brand', 'Model', 'Fuel'] → Columns to encode.
    remainder='passthrough' → Keeps all other columns unchanged.ex = price
"""
# Out:
# " make_column_transformer() → Applies transformations to specific columns.\n    OneHotEncoder() → Converts categorical values into binary columns.\n    ['Brand', 'Model', 'Fuel'] → Columns to encode.\n    remainder='passthrough' → Keeps all other columns unchanged.ex = price\n"

# %%
lr = LinearRegression() #Linear Regression is used to predict a continuous value (e.g., house price, salary, car price).

# %%
pipe = make_pipeline(column_trans,lr)
#Linear Regression is used to predict a continuous value (e.g., house price, salary, car price).
#It first transforms the data (using column_trans).
#Then it trains the Linear Regression model (lr).
#pipeline do transfromation and preict price at a same time that do pipeline

# %%
car = car.loc[:, ~car.columns.str.contains('^Unnamed')]  # Remove any unwanted index column

# Now, proceed with pipeline fitting
X = car[['name', 'company', 'year', 'kms_driven', 'fuel_type']]
y = car['Price']  # Assuming 'price' is the target variable

pipe.fit(X, y)
# Out:
# d:\College\Data science\Anakonda\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
# ...

# %%
pipe.fit(X_train,y_train)
#means that piped data fit that x trained and y trained data
#this code give error because we need to convert data into numeric ordder
# Out:
# d:\College\Data science\Anakonda\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
# ...

# %%
y_pred = pipe.predict(X_test) #this predict result of based on x_test

# %%
y_pred
# Out:
# array([ 269462.13685583,  347990.31733793, 1078081.40068829,
#         694670.19141056,  265640.95239978,  405204.94953558,
#        2182034.9966616 ,  402893.67558382,  410156.76746449,
#         219651.24732039, 2188656.35576823,  371630.87961161,
#         690911.62692764,   29738.85517811,  256951.63691179,
#         174451.28781819,  207231.35329526,  429838.42970267,
#         262480.1372972 ,  385555.66684414,  243218.41841838,
#         521967.15361088,  270494.64627758,  626060.231652  ,
#         187675.24648276,  231028.74430759,  236268.01474726,
#          80410.18179038,  612513.56194381,  298026.02178433,
#         176409.62151291,  364257.94177416,  516335.31582178,
#         224705.41952582,  766646.54921997,  173936.82213456,
#         324402.18446603,  461871.86540131,   74697.40647922,
#          98493.29094775, 1593630.9846059 ,  342535.33629631,
#         395439.38504475,  398478.9907819 ,  117467.08044912,
# ...

# %%
r2_score(y_test,y_pred) #y_test = actual value , y_pred = predicted value
#The R² score tells us how well a regression model predicts the actual values.
# Out:
# 0.19835189225337402

# %%
scores = []
for i in range(1000):
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2, random_state = i)
    lr = LinearRegression()
    pipe = make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred = pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

#r2 score value not fix  train test split they take diffrent data diffrent times
#now we run 1000 time and get highest and maximum r2 score generate 
# The same random numbers are used each time.

# %%
import numpy as np
np.argmax(scores) #random state
# Out:
# 906

# %%
#check max r2 scores 
scores[np.argmax(scores)]
# Out:
# 0.7768124287710744

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2, random_state = np.argmax(scores))
lr = LinearRegression()
pipe = make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.7768124287710744

# %%
car = car.drop(columns=['Unnamed: 0'], errors='ignore')

# %%
import pickle

# %%
pickle.dump(pipe,open('linearRegression.pkl','wb'))
#here passed object pipe which dumped then open it 
#open this file write binnary wb mode
#

# %%
X_test = pd.DataFrame([['Maruti Suzuki Swift', 'Maruti', 2019, 100, 'Petrol']], 
                      columns=['name', 'company', 'year', 'kms_driven', 'fuel_type'])

# Reorder columns to match training data
X_test = X_test.reindex(columns=pipe.feature_names_in_)

prediction = pipe.predict(X_test)
print(prediction)
#created by chatgpt to generate model
# Out:
# [449871.86048038]
